# %%
import pprint
import cPickle

train_data = cPickle.load(open('./data/train_data.pkl'))
for data in train_data[:50]:
    pprint.pprint(data)
# Out:
# {'text': u'ok .',
#  'user_ack': '<YES>',
#  'user_affirm': '<NO>',
#  'user_dont_want_report': '<NO>',
#  'user_finish': '<NO>',
#  'user_inform_day': '<NO>',
#  'user_inform_duration_hour': 24,
#  'user_inform_duration_min': 4,
#  'user_inform_what': '<NO>',
#  'user_inform_whened_hour': 24,
#  'user_inform_whened_min': 4,
#  'user_inform_whenstart_hour': 24,
#  'user_inform_whenstart_min': 4,
#  'user_inform_where': '<NO>',
#  'user_inform_who': '<NO>',
#  'user_report': '<NO>',
#  'user_restart': '<NO>',
#  'user_start': '<NO>'}
# {'text': u'ok .',
#  'user_ack': '<YES>',
#  'user_affirm': '<NO>',
#  'user_dont_want_report': '<NO>',
#  'user_finish': '<NO>',
#  'user_inform_day': '<NO>',
#  'user_inform_duration_hour': 24,
#  'user_inform_duration_min': 4,
#  'user_inform_what': '<NO>',
#  'user_inform_whened_hour': 24,
#  'user_inform_whened_min': 4,
#  'user_inform_whenstart_hour': 24,
#  'user_inform_whenstart_min': 4,
#  'user_inform_where': '<NO>',
# ...
